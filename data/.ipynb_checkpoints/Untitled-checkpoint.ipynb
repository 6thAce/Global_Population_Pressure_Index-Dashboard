# %%
import pandas as pd

# %%
pop = pd.read_csv("fact_population_un.csv")
econ = pd.read_csv("fact_economics_imf.xls.csv")
water = pd.read_csv("fact_water_access.csv")
base = pd.read_csv("fact_country_year.csv")
country = pd.read_csv("dim_country_lookup.csv")

# %%
pop.head()
econ.head()
water.head()
base.head()
# Out:
#                           COUNTRY      1980      1981      1982      1983  \
# 0  Liechtenstein, Principality of       NaN       NaN       NaN       NaN
# 1                          Canada    10.980    11.304    10.951    11.024
# 2                        Honduras  2160.861  2133.804  2183.575  2222.247
# 3                        Honduras     3.673     3.790     3.908     4.029
# 4                    Bahamas, The     0.211     0.215     0.220     0.225
#
#        1984      1985      1986      1987      1988  ...       2021  \
# 0       NaN       NaN       NaN       NaN       NaN  ...      0.041
# 1    11.302    11.657    12.004    12.332    12.711  ...     18.973
# 2  2366.597  2464.850  2574.283  2724.965  2938.810  ...  66813.898
# 3     4.154     4.283     4.411     4.544     4.680  ...     10.117
# 4     0.230     0.234     0.238     0.242     0.247  ...      0.394
#
#         2022       2023       2024       2025        2026        2027  \
# 0      0.043      0.043      0.044      0.045       0.046         NaN
# 1     19.748     20.341     20.723     21.009      21.080         NaN
# 2  74749.009  80686.569  86300.122  95066.366  100495.041  106338.384
# 3     10.294     10.475     10.659     10.846      11.037      11.231
# 4      0.399      0.404      0.408      0.413       0.417       0.421
#
#          2028        2029        2030
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2  112815.742  119722.508  126957.554
# 3      11.428      11.629      11.833
# 4       0.425       0.429       0.434
#
# [5 rows x 52 columns]

# %%
pop.columns
# Out:
# Index(['country', 'year', 'population', 'population_growth_rate'], dtype='str')

# %%
pop = pop.rename(columns={
    "Location": "country",
    "Time": "year",
    "TPopulation1Jan": "population",
    "PopGrowthRate": "population_growth_rate"
})

pop = pop[["country", "year", "population", "population_growth_rate"]]

# %%
pop["year"] = pd.to_numeric(pop["year"], errors="coerce")
pop["population"] = pd.to_numeric(pop["population"], errors="coerce")
pop["population_growth_rate"] = pd.to_numeric(pop["population_growth_rate"], errors="coerce")

# %%
pop = pop.dropna()
pop = pop.drop_duplicates(subset=["country", "year"])

# %%
water = water.rename(columns={
    "name": "country",
    "wat_basal_t": "basic_water_access_total"
})

water = water[["country", "year", "basic_water_access_total"]]

water["year"] = pd.to_numeric(water["year"], errors="coerce")
water["basic_water_access_total"] = pd.to_numeric(water["basic_water_access_total"], errors="coerce")

water = water.dropna()
